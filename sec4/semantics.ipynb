# %% [markdown]
# # 語意運算實作

# %%
# %matplotlib inline

# %%
from __future__ import absolute_import
from __future__ import print_function
import collections
import math
import os
import random
import zipfile
import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf
tf.set_random_seed(1234)

# %% [markdown]
# ## 1. 下載訓練資料

# %%
url = 'http://mattmahoney.net/dc/'


def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename


filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = f.read(f.namelist()[0]).split()
    return data


words = read_data(filename)
print('Data size', len(words))
# Out:
# Data size 17005207

# %%
words[:10]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against']

# %%
" ".join(words[:50])
# Out:
# 'anarchism originated as a term of abuse first used against early working class radicals including the diggers of the english revolution and the sans culottes of the french revolution whilst the term is still used in a pejorative way to describe any act that used violent means to destroy the'

# %% [markdown]
# ## 2. 前處理，建立字典，並將極少出現的自用UNL代替

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary


data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:50])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156, 128, 742, 477, 10572, 134, 1, 27549, 2, 1, 103, 855, 3, 1, 15068, 0, 2, 1, 151, 855, 3583, 1, 195, 11, 191, 59, 5, 6, 10742, 215, 7, 1326, 105, 455, 20, 59, 2734, 363, 7, 3676, 1]

# %%
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:50])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156, 128, 742, 477, 10572, 134, 1, 27549, 2, 1, 103, 855, 3, 1, 15068, 0, 2, 1, 151, 855, 3583, 1, 195, 11, 191, 59, 5, 6, 10742, 215, 7, 1326, 105, 455, 20, 59, 2734, 363, 7, 3676, 1]

# %% [markdown]
# ## 3. 前處理，產生訓練用的batch

# %%
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels


batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
    print('ids:',batch[i], '->', labels[i, 0])
    print('words:',reverse_dictionary[batch[i]], '->', reverse_dictionary[labels[i, 0]])
# Out:
# ids: 3084 -> 5239
# words: originated -> anarchism
# ids: 3084 -> 12
# words: originated -> as
# ids: 12 -> 6
# words: as -> a
# ids: 12 -> 3084
# words: as -> originated
# ids: 6 -> 195
# words: a -> term
# ids: 6 -> 12
# words: a -> as
# ids: 195 -> 2
# words: term -> of
# ids: 195 -> 6
# words: term -> a

# %% [markdown]
# ## 4. 建立computational Graph

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():
    # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    loss = tf.reduce_mean(
        tf.nn.nce_loss(nce_weights, nce_biases, embed, train_labels,
                       num_sampled, vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

# %% [markdown]
# ## 5. 訓練word2vec神經網路

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    tf.initialize_all_variables().run()
    print("Initialized")

    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = "Nearest to %s:" % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  288.394866943
# Nearest to may: antikythera, wrists, fernand, ortiz, leach, steinberg, khanna, ceded,
# Nearest to with: terraced, phillips, ii, ar, eminent, brazil, redefinition, deportation,
# Nearest to this: disarming, impress, steven, alternates, slogan, shaft, legge, entrepreneurial,
# Nearest to or: greeneville, tardis, wenders, barbara, cyclone, expresses, thackeray, crs,
# Nearest to if: serapeum, curdled, goers, ordinarily, blankets, desi, seriously, bamako,
# Nearest to people: duns, ariane, baden, partements, fantastical, michel, andrzej, asn,
# Nearest to on: comm, xml, mes, pouches, democr, neuromuscular, yeshiva, bedrock,
# Nearest to called: administer, purity, ibrahim, haldeman, optics, xxxvii, pumpkin, kenya,
# Nearest to can: mfm, kling, sanitarium, canonical, botanist, rda, buildings, athleticism,
# Nearest to to: communes, boundless, stalingrad, study, albertosaurus, tsushima, incorrectly, route,
# Nearest to all: congolese, saxophonist, phrases, lips, fertilized, siam, wrappings, dolls,
# Nearest to the: portrayed, every, hayao, notices, woodlands, unworkable, altman, yusuf,
# Nearest to system: pseudo, coeducational, beans, berthold, instinctively, representationalism, mnism, herself,
# Nearest to zero: digital, predestination, numb, tactically, spectators, brando, ford, tambo,
# Nearest to state: entering, anjiro, herbivore, hyperinflation, nne, mma, viewing, appear,
# Nearest to would: acorn, swearing, depends, teen, prokaryotic, ayla, truck, exactly,
# Average loss at step  2000 :  113.835994227
# Average loss at step  4000 :  52.7114883597
# Average loss at step  6000 :  33.5301543615
# Average loss at step  8000 :  23.5879121871
# Average loss at step  10000 :  17.5867392889
# Nearest to may: solstice, nine, dynasties, agave, allied, victoriae, affidavit, cl,
# Nearest to with: in, and, of, ii, occupational, mya, omnibus, for,
# Nearest to this: the, ingrid, waite, riverside, vs, victoriae, ignosticism, mathbf,
# Nearest to or: and, interactions, vila, victoriae, virulent, s, expresses, philip,
# Nearest to if: victoriae, is, completion, found, logo, emerged, seriously, critical,
# Nearest to people: universe, pamphlet, dates, mourned, bring, railroad, head, isopropyl,
# Nearest to on: in, from, reginae, nuremberg, and, shore, hardware, of,
# Nearest to called: purity, kenya, ibrahim, extremely, administer, fifth, approval, clan,
# Nearest to can: phalanx, established, while, si, mall, degrees, cc, and,
# Nearest to to: and, nine, bands, in, mathbf, of, theater, author,
# Nearest to all: standing, amplifier, congolese, phi, much, years, lips, cultures,
# Nearest to the: a, UNK, and, his, cl, analogue, reginae, aarhus,
# Nearest to system: basic, pseudo, implicit, calling, consumer, september, omega, mathbf,
# Nearest to zero: nine, austin, six, mathbf, vs, eight, pottery, one,
# Nearest to state: leonard, entering, cell, mya, appear, viewing, cl, aa,
# Nearest to would: truck, depends, swearing, launches, oxide, must, augustin, dominated,
# Average loss at step  12000 :  14.0816940738
# Average loss at step  14000 :  12.0063339248
# Average loss at step  16000 :  9.90680144787
# Average loss at step  18000 :  8.67882600927
# Average loss at step  20000 :  7.77568630838
# Nearest to may: solstice, nine, must, agouti, dynasties, ceded, allied, wrists,
# Nearest to with: in, for, by, and, of, from, imran, nine,
# Nearest to this: the, it, a, that, which, ingrid, mercenary, aquila,
# Nearest to or: and, agouti, s, see, dasyprocta, eight, interactions, attribute,
# Nearest to if: is, serapeum, victoriae, dasyprocta, bros, completion, alignment, found,
# Nearest to people: ariane, dates, pamphlet, baden, mourned, universe, amphitryon, isopropyl,
# Nearest to on: in, from, agouti, and, reginae, dasyprocta, at, for,
# Nearest to called: purity, ibrahim, dasyprocta, administer, impression, extremely, kenya, and,
# Nearest to can: would, phalanx, may, while, but, resurrection, and, dasyprocta,
# Nearest to to: for, in, nine, by, imran, and, arag, mathbf,
# Nearest to all: amplifier, much, standing, vermont, location, dasyprocta, any, agouti,
# Nearest to the: a, his, their, one, this, its, dasyprocta, agouti,
# Nearest to system: dasyprocta, pseudo, implicit, basic, meals, calling, unarable, omega,
# Nearest to zero: nine, eight, five, six, seven, three, agouti, four,
# Nearest to state: ames, UNK, monmouth, agouti, entering, appear, mya, specimen,
# Nearest to would: can, must, launches, truck, augustin, wcw, engraving, depends,
# Average loss at step  22000 :  7.18299278569
# Average loss at step  24000 :  6.87931610894
# Average loss at step  26000 :  6.72393906665
# Average loss at step  28000 :  6.22493607795
# Average loss at step  30000 :  6.18725007796
# Nearest to may: can, must, solstice, nine, would, could, ceded, dynasties,
# Nearest to with: in, by, for, and, from, abet, or, of,
# Nearest to this: the, it, a, which, abitibi, that, aquila, abwehr,
# Nearest to or: and, abet, agouti, reuptake, dasyprocta, than, s, see,
# Nearest to if: is, victoriae, serapeum, amalthea, but, dasyprocta, completion, alignment,
# Nearest to people: ariane, dates, baden, pamphlet, bos, mourned, hokkaido, isopropyl,
# Nearest to on: in, from, agouti, reginae, with, at, and, for,
# Nearest to called: purity, ibrahim, administer, dasyprocta, extremely, impression, akita, trs,
# Nearest to can: would, may, could, will, to, but, is, dasyprocta,
# Nearest to to: for, in, aba, and, will, nine, imran, by,
# Nearest to all: any, aba, vermont, biochemistry, amplifier, dasyprocta, location, much,
# Nearest to the: his, their, a, its, this, agouti, akita, dasyprocta,
# Nearest to system: dasyprocta, unarable, pseudo, implicit, basic, primigenius, meals, omega,
# Nearest to zero: five, eight, six, nine, seven, four, three, agouti,
# Nearest to state: ames, UNK, agouti, monmouth, aorta, entering, mya, akita,
# Nearest to would: can, must, could, will, may, launches, truck, to,
# Average loss at step  32000 :  5.82292123079
# Average loss at step  34000 :  5.83099703002
# Average loss at step  36000 :  5.68333857429
# Average loss at step  38000 :  5.25127649355
# Average loss at step  40000 :  5.43591694719
# Nearest to may: can, must, would, could, will, solstice, steinberg, ceded,
# Nearest to with: in, and, for, abet, from, by, adiabatic, or,
# Nearest to this: it, which, the, that, abitibi, a, trough, aquila,
# Nearest to or: and, abet, four, than, agouti, reuptake, dasyprocta, three,
# Nearest to if: is, victoriae, but, amalthea, serapeum, when, dasyprocta, alignment,
# Nearest to people: ariane, baden, dates, hokkaido, mourned, amphitryon, isopropyl, pamphlet,
# Nearest to on: in, from, at, agouti, dasyprocta, reginae, and, with,
# Nearest to called: purity, ibrahim, dasyprocta, and, akita, administer, extremely, astoria,
# Nearest to can: would, may, will, could, to, but, dasyprocta, while,
# Nearest to to: albury, for, can, aba, will, and, from, nine,
# Nearest to all: any, aba, vermont, three, amplifier, dasyprocta, two, biochemistry,
# Nearest to the: their, his, its, a, this, agouti, akita, dasyprocta,
# Nearest to system: unarable, dasyprocta, implicit, pseudo, basic, beans, meals, mathbf,
# Nearest to zero: five, nine, seven, eight, six, four, three, agouti,
# Nearest to state: ames, monmouth, agouti, nne, mya, aorta, compression, entering,
# Nearest to would: can, must, could, will, may, launches, augustin, truck,
# Average loss at step  42000 :  5.31227859676
# Average loss at step  44000 :  5.44017823911
# Average loss at step  46000 :  5.29364753675
# Average loss at step  48000 :  5.0249338727
# Average loss at step  50000 :  5.17470910239
# Nearest to may: can, must, would, could, will, steinberg, ortiz, ceded,
# Nearest to with: in, by, abet, for, and, debating, from, adiabatic,
# Nearest to this: it, which, the, abitibi, that, one, nguni, thibetanus,
# Nearest to or: and, abet, than, four, dasyprocta, seven, agouti, three,
# Nearest to if: when, is, but, victoriae, amalthea, are, dasyprocta, serapeum,
# Nearest to people: ariane, thibetanus, isopropyl, hokkaido, amphitryon, baden, dates, mourned,
# Nearest to on: in, at, from, agouti, dasyprocta, through, two, thibetanus,
# Nearest to called: purity, ibrahim, thibetanus, dasyprocta, and, akita, extremely, administer,
# Nearest to can: would, could, will, may, to, must, eight, incorrectly,
# Nearest to to: albury, aba, will, can, eight, mohamed, nine, for,
# Nearest to all: any, vermont, aba, two, dasyprocta, three, roshan, some,
# Nearest to the: their, his, its, a, agouti, akita, this, dasyprocta,
# Nearest to system: beans, unarable, pseudo, meals, basic, implicit, sergeant, dasyprocta,
# Nearest to zero: five, eight, seven, six, four, nine, three, two,
# Nearest to state: ames, nne, monmouth, agouti, compression, aorta, mya, nautical,
# Nearest to would: can, will, could, must, may, launches, to, augustin,
# Average loss at step  52000 :  5.16694956803
# Average loss at step  54000 :  5.08173843026
# Average loss at step  56000 :  5.06313667428
# Average loss at step  58000 :  5.12791225004
# Average loss at step  60000 :  4.9409106847
# Nearest to may: can, must, would, could, will, steinberg, should, ortiz,
# Nearest to with: in, callithrix, by, abet, and, or, debating, for,
# Nearest to this: it, which, the, that, abitibi, a, callithrix, there,
# Nearest to or: and, callithrix, tamarin, abet, dasyprocta, microcebus, agouti, than,
# Nearest to if: when, is, but, where, victoriae, callithrix, microsite, lush,
# Nearest to people: microcebus, ariane, isopropyl, marmoset, hokkaido, mourned, baden, thibetanus,
# Nearest to on: in, at, callithrix, from, agouti, microcebus, dasyprocta, through,
# Nearest to called: purity, callithrix, marmoset, thibetanus, ibrahim, and, akita, dasyprocta,
# Nearest to can: would, could, may, will, must, to, callithrix, might,
# Nearest to to: albury, will, aba, can, callithrix, nine, for, mohamed,
# Nearest to all: some, any, vermont, aba, two, many, dasyprocta, michelob,
# Nearest to the: their, its, his, this, a, akita, callithrix, tamarin,
# Nearest to system: unarable, beans, dasyprocta, pseudo, meals, implicit, knitting, basic,
# Nearest to zero: eight, five, six, seven, nine, four, saguinus, three,
# Nearest to state: ames, nne, agouti, tamarin, monmouth, mya, aorta, cell,
# Nearest to would: can, will, could, may, must, to, callithrix, launches,
# Average loss at step  62000 :  4.77983024931
# Average loss at step  64000 :  4.79915090275
# Average loss at step  66000 :  4.95837401295
# Average loss at step  68000 :  4.91762587011
# Average loss at step  70000 :  4.76942834163
# Nearest to may: can, must, would, will, could, might, should, to,
# Nearest to with: in, callithrix, abet, adiabatic, between, or, debating, and,
# Nearest to this: it, which, the, that, abitibi, callithrix, some, aquila,
# Nearest to or: and, callithrix, abet, tamarin, than, dasyprocta, cebus, marmoset,
# Nearest to if: when, is, but, where, callithrix, victoriae, microsite, lush,
# Nearest to people: microcebus, ariane, hokkaido, isopropyl, marmoset, bosnia, mourned, thibetanus,
# Nearest to on: in, at, callithrix, through, agouti, from, microcebus, dasyprocta,
# Nearest to called: purity, callithrix, marmoset, thibetanus, akita, microcebus, ibrahim, dasyprocta,
# Nearest to can: would, may, could, will, must, to, callithrix, might,
# Nearest to to: will, can, albury, aba, mohamed, not, for, callithrix,
# Nearest to all: some, any, vermont, many, these, aba, three, michelob,
# Nearest to the: their, its, his, this, callithrix, a, agouti, tamarin,
# Nearest to system: unarable, beans, meals, dasyprocta, knitting, pseudo, implicit, sergeant,
# Nearest to zero: five, eight, six, seven, four, nine, saguinus, three,
# Nearest to state: ames, nne, mya, tamarin, agouti, monmouth, cell, keel,
# Nearest to would: can, will, may, could, must, to, should, might,
# Average loss at step  72000 :  4.81355784512
# Average loss at step  74000 :  4.7847743488
# Average loss at step  76000 :  4.88206703961
# Average loss at step  78000 :  4.80792991567
# Average loss at step  80000 :  4.81315114856
# Nearest to may: can, must, would, will, could, might, should, to,
# Nearest to with: in, callithrix, abet, between, by, or, adiabatic, debating,
# Nearest to this: it, which, the, abitibi, that, callithrix, aquila, thibetanus,
# Nearest to or: and, than, callithrix, tamarin, abet, dasyprocta, marmoset, cebus,
# Nearest to if: when, where, but, victoriae, callithrix, dreamers, microsite, dasyprocta,
# Nearest to people: microcebus, rasterization, ariane, hokkaido, mourned, bosnia, isopropyl, marmoset,
# Nearest to on: in, at, through, callithrix, agouti, from, during, upon,
# Nearest to called: purity, callithrix, marmoset, thibetanus, akita, microcebus, apotheosis, antidepressants,
# Nearest to can: would, may, could, will, must, should, might, to,
# Nearest to to: aba, will, albury, callithrix, mohamed, can, would, imran,
# Nearest to all: some, many, any, vermont, these, aba, clodius, dasyprocta,
# Nearest to the: their, its, callithrix, his, akita, this, tamarin, agouti,
# Nearest to system: beans, unarable, meals, pseudo, dasyprocta, knitting, implicit, sergeant,
# Nearest to zero: five, six, eight, seven, four, nine, saguinus, three,
# Nearest to state: ames, nne, agouti, tamarin, mya, aorta, monmouth, pontificia,
# Nearest to would: can, will, may, could, must, should, might, did,
# Average loss at step  82000 :  4.78989894462
# Average loss at step  84000 :  4.78661209917
# Average loss at step  86000 :  4.74181861258
# Average loss at step  88000 :  4.68696327031
# Average loss at step  90000 :  4.75213474584
# Nearest to may: can, must, would, could, will, might, should, microsite,
# Nearest to with: in, between, callithrix, or, abet, from, adiabatic, debating,
# Nearest to this: it, which, the, abitibi, some, that, tamias, another,
# Nearest to or: and, callithrix, tamarin, than, abet, dasyprocta, cebus, marmoset,
# Nearest to if: when, where, victoriae, callithrix, dasyprocta, but, dreamers, tamarin,
# Nearest to people: microcebus, rasterization, bosnia, mesoplodon, mourned, hokkaido, isopropyl, ariane,
# Nearest to on: in, at, callithrix, agouti, through, from, upon, microcebus,
# Nearest to called: callithrix, purity, marmoset, akita, thibetanus, antidepressants, microcebus, apotheosis,
# Nearest to can: may, would, could, will, must, might, should, to,
# Nearest to to: will, can, albury, aba, nine, mohamed, would, imran,
# Nearest to all: some, many, any, vermont, these, clodius, aba, each,
# Nearest to the: its, their, this, callithrix, a, his, akita, agouti,
# Nearest to system: unarable, beans, dasyprocta, meals, cuauht, pseudo, knitting, implicit,
# Nearest to zero: five, seven, eight, six, nine, four, saguinus, three,
# Nearest to state: peacocks, nne, ames, agouti, tamarin, mya, nautical, monmouth,
# Nearest to would: can, will, may, could, must, might, should, did,
# Average loss at step  92000 :  4.70777410483
# Average loss at step  94000 :  4.61838468564
# Average loss at step  96000 :  4.71979125035
# Average loss at step  98000 :  4.62908300745
# Average loss at step  100000 :  4.66993997478
# Nearest to may: can, would, must, could, will, might, should, cannot,
# Nearest to with: between, in, callithrix, adiabatic, or, abet, by, debating,
# Nearest to this: it, which, the, that, abitibi, some, aquila, another,
# Nearest to or: and, callithrix, than, tamarin, abet, dasyprocta, duesberg, cebus,
# Nearest to if: when, where, victoriae, callithrix, dasyprocta, although, dreamers, though,
# Nearest to people: microcebus, mesoplodon, rasterization, bosnia, mourned, hokkaido, isopropyl, dee,
# Nearest to on: in, at, through, upon, agouti, callithrix, during, from,
# Nearest to called: callithrix, purity, marmoset, akita, thibetanus, antidepressants, microcebus, and,
# Nearest to can: may, would, could, will, must, should, might, to,
# Nearest to to: albury, will, aba, can, callithrix, would, nine, microcebus,
# Nearest to all: some, many, any, these, aba, vermont, both, clodius,
# Nearest to the: their, its, his, akita, this, callithrix, some, marmoset,
# Nearest to system: unarable, meals, beans, pseudo, cuauht, dasyprocta, knitting, implicit,
# Nearest to zero: five, eight, seven, six, four, nine, saguinus, tamarin,
# Nearest to state: nne, peacocks, ames, agouti, tamarin, nautical, mya, aorta,
# Nearest to would: can, will, could, may, must, might, should, did,

# %% [markdown]
# ## 6. 以視覺化的方式呈現結果

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.savefig(filename)
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
labels = [reverse_dictionary[i] for i in xrange(plot_only)]
plot_with_labels(low_dim_embs, labels)
