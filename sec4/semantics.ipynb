# %% [markdown]
# # 語意運算實作

# %%
# %matplotlib inline

# %%
from __future__ import absolute_import
from __future__ import print_function
import collections
import math
import os
import random
import zipfile
import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf
tf.set_random_seed(1234)

# %% [markdown]
# ## 1. 下載訓練資料

# %%
url = 'http://mattmahoney.net/dc/'


def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename


filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = f.read(f.namelist()[0]).split()
    return data


words = read_data(filename)
print('Data size', len(words))
# Out:
# Data size 17005207

# %%
words[:10]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against']

# %%
" ".join(words[:50])
# Out:
# 'anarchism originated as a term of abuse first used against early working class radicals including the diggers of the english revolution and the sans culottes of the french revolution whilst the term is still used in a pejorative way to describe any act that used violent means to destroy the'

# %% [markdown]
# ## 2. 前處理，建立字典，並將極少出現的自用UNL代替

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary


data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156, 128, 742, 477, 10572, 134, 1, 27549, 2, 1, 103, 855, 3, 1, 15068, 0, 2, 1, 151, 855, 3583, 1, 195, 11, 191, 59, 5, 6, 10742, 215, 7, 1326, 105, 455, 20, 59, 2734, 363, 7, 3676, 1]

# %%
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:50])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156, 128, 742, 477, 10572, 134, 1, 27549, 2, 1, 103, 855, 3, 1, 15068, 0, 2, 1, 151, 855, 3583, 1, 195, 11, 191, 59, 5, 6, 10742, 215, 7, 1326, 105, 455, 20, 59, 2734, 363, 7, 3676, 1]

# %% [markdown]
# ## 3. 前處理，產生訓練用的batch

# %%
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels


batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
    print('ids:',batch[i], '->', labels[i, 0])
    print('words:',reverse_dictionary[batch[i]], '->', reverse_dictionary[labels[i, 0]])
# Out:
# ids: 3084 -> 12
# words: originated -> as
# ids: 3084 -> 5239
# words: originated -> anarchism
# ids: 12 -> 3084
# words: as -> originated
# ids: 12 -> 6
# words: as -> a
# ids: 6 -> 195
# words: a -> term
# ids: 6 -> 12
# words: a -> as
# ids: 195 -> 6
# words: term -> a
# ids: 195 -> 2
# words: term -> of

# %% [markdown]
# ## 4. 建立computational Graph

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():
    # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    loss = tf.reduce_mean(
        tf.nn.nce_loss(nce_weights, nce_biases, embed, train_labels,
                       num_sampled, vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

# %% [markdown]
# ## 5. 訓練word2vec神經網路

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    tf.initialize_all_variables().run()
    print("Initialized")

    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step %s : %s"%(step, average_loss))
            average_loss = 0

        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = "Nearest to %s:" % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0 : 257.825805664
# Nearest to between: redeem, authorizing, treatises, liberation, agora, clarify, seventy, mariah,
# Nearest to zero: fin, homogenized, rapport, stow, langley, radios, dare, tanzanian,
# Nearest to as: rinse, sheppard, pluralism, junk, salute, vend, tagline, catalysts,
# Nearest to its: ev, dissonance, wheeling, bonzo, critical, sioux, ironically, micron,
# Nearest to these: supersonic, satirized, muggles, expensive, stalingrad, vers, full, atoll,
# Nearest to and: buying, dolphins, subfamilies, fingertips, ruth, ack, projects, vans,
# Nearest to d: retort, steyn, attitude, gulag, veyron, propagate, joanne, iiis,
# Nearest to will: mayoral, meps, joost, rendition, vitamins, existentialists, batteries, penang,
# Nearest to be: benediction, shameful, sheila, ferreira, eusebio, redman, nde, zant,
# Nearest to time: slavonia, por, privateer, gut, gesture, tradeoff, enact, soon,
# Nearest to but: netherland, larwood, him, kom, untrustworthy, multistage, comic, headaches,
# Nearest to to: identities, denunciations, mayflower, meissen, paine, solenoid, phallus, stratified,
# Nearest to while: ire, bird, demoness, conciliator, thracian, substratum, descriptive, giza,
# Nearest to years: tanto, dea, accommodating, vilified, genitive, bourdieu, cygnus, winged,
# Nearest to many: bengalis, pardoned, millet, tigers, vary, altitude, sasl, eldorado,
# Nearest to by: refine, imprecise, views, toronto, gniezno, cern, talbot, crucifixion,
# Average loss at step 2000 : 113.587967809
# Average loss at step 4000 : 52.438199847
# Average loss at step 6000 : 33.5579107561
# Average loss at step 8000 : 23.7874410764
# Average loss at step 10000 : 17.7295387213
# Nearest to between: in, portuguese, liberation, gland, of, daily, define, spots,
# Nearest to zero: nine, gland, vs, mathbf, phi, reginae, six, agave,
# Nearest to as: amo, and, reginae, in, for, victoriae, oceans, alien,
# Nearest to its: the, gland, stewart, dispute, ev, critical, pick, ra,
# Nearest to these: agave, altenberg, et, tissue, arches, claim, watch, the,
# Nearest to and: of, in, UNK, one, or, for, phi, analogue,
# Nearest to d: attitude, mathbf, one, period, offer, phi, type, reality,
# Nearest to will: three, breath, mathbf, vitamins, batteries, explanation, coincide, von,
# Nearest to be: benediction, planning, quantum, dispute, computer, is, foreign, have,
# Nearest to time: gland, soon, definition, mathbf, slave, mutation, sports, prove,
# Nearest to but: him, yo, and, flew, phi, vs, for, ampere,
# Nearest to to: analogue, and, reflects, in, eagle, paine, for, gland,
# Nearest to while: bird, internet, out, doctor, giza, warfare, descriptive, aardvark,
# Nearest to years: sigma, tanto, winged, manga, immediately, hear, genitive, discipline,
# Nearest to many: agave, sin, vary, benediction, amo, altitude, victoriae, foreign,
# Nearest to by: with, in, for, amo, resistivity, and, vs, refine,
# Average loss at step 12000 : 14.3036858448
# Average loss at step 14000 : 11.8339441776
# Average loss at step 16000 : 9.85612591791
# Average loss at step 18000 : 8.55013197768
# Average loss at step 20000 : 7.81450693524
# Nearest to between: in, of, and, liberation, portuguese, or, gland, abruptly,
# Nearest to zero: seven, nine, five, six, eight, three, two, four,
# Nearest to as: for, and, in, amo, dasyprocta, by, is, into,
# Nearest to its: the, his, ibrahim, a, associativity, dispute, stewart, pick,
# Nearest to these: the, agave, altenberg, aut, watch, satirized, iphigenia, pediatric,
# Nearest to and: or, in, dasyprocta, phi, of, for, UNK, from,
# Nearest to d: b, mathbf, and, attitude, period, offer, dasyprocta, phi,
# Nearest to will: vitamins, made, gamemasters, sentenced, breath, juliana, three, manners,
# Nearest to be: have, is, benediction, dasyprocta, was, by, planning, computer,
# Nearest to time: dasyprocta, privateer, incompressible, slave, gland, soon, definition, gut,
# Nearest to but: and, yo, for, metis, him, is, vs, flew,
# Nearest to to: analogue, for, and, reflects, in, nine, paine, would,
# Nearest to while: bird, and, but, internet, of, over, nickname, in,
# Nearest to years: sigma, tanto, compiler, manga, genitive, winged, two, interbreed,
# Nearest to many: agave, sin, his, vary, the, altitude, gregorian, absalom,
# Nearest to by: with, in, for, was, is, and, from, dasyprocta,
# Average loss at step 22000 : 7.25363992274
# Average loss at step 24000 : 6.94076799607
# Average loss at step 26000 : 6.71416777039
# Average loss at step 28000 : 6.19055368543
# Average loss at step 30000 : 6.14780781829
# Nearest to between: in, of, on, abruptly, philistines, with, portuguese, liberation,
# Nearest to zero: eight, seven, five, six, nine, four, three, two,
# Nearest to as: and, for, dasyprocta, amo, is, by, in, chalukyas,
# Nearest to its: the, his, their, ibrahim, a, some, invaded, associativity,
# Nearest to these: the, agave, altenberg, watch, supersonic, aut, mount, pediatric,
# Nearest to and: or, abet, in, phi, dasyprocta, aba, of, for,
# Nearest to d: b, propagate, one, mathbf, phi, and, dasyprocta, bayer,
# Nearest to will: would, made, abet, sentenced, gamemasters, trinomial, antipsychotics, ethel,
# Nearest to be: have, is, by, was, are, dasyprocta, benediction, akh,
# Nearest to time: reuptake, dasyprocta, privateer, gut, por, slave, incompressible, abitibi,
# Nearest to but: and, yo, akita, vs, phi, is, dasyprocta, metis,
# Nearest to to: analogue, through, paine, would, for, reflects, nine, aba,
# Nearest to while: bird, and, but, over, of, were, for, internet,
# Nearest to years: two, shunt, tanto, genitive, sigma, manga, winged, dn,
# Nearest to many: agave, the, sin, any, vary, altitude, some, several,
# Nearest to by: with, in, was, from, for, as, and, dasyprocta,
# Average loss at step 32000 : 5.86907079005
# Average loss at step 34000 : 5.82554180634
# Average loss at step 36000 : 5.67479877615
# Average loss at step 38000 : 5.25206342185
# Average loss at step 40000 : 5.4564193871
# Nearest to between: in, on, of, with, abruptly, philistines, portuguese, above,
# Nearest to zero: five, six, seven, eight, nine, four, three, two,
# Nearest to as: amo, by, dasyprocta, chalukyas, is, and, became, in,
# Nearest to its: the, their, his, a, some, ibrahim, compositions, invaded,
# Nearest to these: agave, the, watch, altenberg, which, are, analysts, mount,
# Nearest to and: or, phi, abet, dasyprocta, but, aba, in, akita,
# Nearest to d: b, UNK, zero, propagate, phi, offer, attitude, mathbf,
# Nearest to will: would, gamemasters, should, sentenced, made, abet, ethel, may,
# Nearest to be: have, is, by, are, were, was, been, dasyprocta,
# Nearest to time: reuptake, dasyprocta, gut, privateer, por, abitibi, ruse, incompressible,
# Nearest to but: and, that, yo, while, akita, which, metis, dasyprocta,
# Nearest to to: through, reflects, analogue, would, paine, nine, from, for,
# Nearest to while: but, bird, and, over, synchronisation, were, are, internet,
# Nearest to years: shunt, three, tanto, dn, genitive, winged, accommodating, interbreed,
# Nearest to many: some, agave, several, any, vary, the, altitude, sin,
# Nearest to by: was, with, be, as, for, in, from, dasyprocta,
# Average loss at step 42000 : 5.28297581422
# Average loss at step 44000 : 5.26463727176
# Average loss at step 46000 : 5.25456905043
# Average loss at step 48000 : 5.02217381716
# Average loss at step 50000 : 5.16776960146
# Nearest to between: in, with, nine, on, tejada, abruptly, of, philistines,
# Nearest to zero: eight, six, five, nine, seven, four, three, two,
# Nearest to as: amo, thibetanus, naaman, dasyprocta, by, became, is, chalukyas,
# Nearest to its: their, the, his, some, ibrahim, a, compositions, associativity,
# Nearest to these: some, watch, many, which, agave, are, such, other,
# Nearest to and: or, but, abet, phi, thibetanus, in, dasyprocta, aba,
# Nearest to d: b, propagate, UNK, zero, offer, phi, attitude, hvac,
# Nearest to will: would, should, can, may, could, gamemasters, sentenced, abet,
# Nearest to be: have, by, was, is, were, are, been, dasyprocta,
# Nearest to time: reuptake, dasyprocta, privateer, ruse, gut, abitibi, por, incompressible,
# Nearest to but: and, while, prism, dasyprocta, which, akita, vs, yo,
# Nearest to to: would, through, analogue, paine, reflects, nine, can, initiating,
# Nearest to while: but, and, synchronisation, bird, thibetanus, over, or, were,
# Nearest to years: shunt, dn, tanto, genitive, winged, interbreed, accommodating, pca,
# Nearest to many: some, several, agave, these, such, any, altitude, the,
# Nearest to by: was, with, be, as, beeb, from, dasyprocta, in,
# Average loss at step 52000 : 5.18449950886
# Average loss at step 54000 : 5.12005079448
# Average loss at step 56000 : 5.0895911417
# Average loss at step 58000 : 5.10806875801
# Average loss at step 60000 : 4.95481963342
# Nearest to between: in, with, microcebus, cebus, abruptly, tejada, on, michelob,
# Nearest to zero: eight, five, six, seven, nine, four, three, callithrix,
# Nearest to as: amo, thibetanus, naaman, became, dasyprocta, chalukyas, microcebus, in,
# Nearest to its: their, his, the, some, ibrahim, a, sylia, cebus,
# Nearest to these: some, many, watch, such, the, which, all, other,
# Nearest to and: or, but, abet, dasyprocta, microcebus, thibetanus, callithrix, aba,
# Nearest to d: b, propagate, zero, hvac, offer, etext, microcebus, dasyprocta,
# Nearest to will: would, can, may, should, could, gamemasters, sentenced, did,
# Nearest to be: been, have, by, was, were, is, are, akh,
# Nearest to time: reuptake, dasyprocta, privateer, ruse, gut, abitibi, michelob, callithrix,
# Nearest to but: and, while, or, although, prism, however, dasyprocta, which,
# Nearest to to: would, analogue, through, paine, nine, not, for, can,
# Nearest to while: but, and, thibetanus, synchronisation, were, over, bird, or,
# Nearest to years: shunt, dn, genitive, tanto, interbreed, pca, winged, three,
# Nearest to many: some, several, these, such, agave, microcebus, two, scratched,
# Nearest to by: was, with, be, dasyprocta, as, been, microcebus, callithrix,
# Average loss at step 62000 : 4.78847849417
# Average loss at step 64000 : 4.80896675277
# Average loss at step 66000 : 4.96837298477
# Average loss at step 68000 : 4.91721112859
# Average loss at step 70000 : 4.76614037848
# Nearest to between: in, with, microcebus, tejada, clo, abruptly, during, cebus,
# Nearest to zero: eight, five, six, seven, four, nine, three, michelob,
# Nearest to as: amo, thibetanus, chalukyas, dasyprocta, became, in, microcebus, naaman,
# Nearest to its: their, the, his, some, a, saguinus, ibrahim, compositions,
# Nearest to these: some, many, such, which, other, all, watch, the,
# Nearest to and: or, but, abet, microcebus, thibetanus, dasyprocta, upanija, callithrix,
# Nearest to d: b, propagate, UNK, thaler, soy, hvac, venezuela, offer,
# Nearest to will: would, can, may, could, should, upanija, must, did,
# Nearest to be: been, by, have, is, were, are, was, not,
# Nearest to time: reuptake, dasyprocta, privateer, ruse, abitibi, michelob, por, preserve,
# Nearest to but: and, while, however, or, prism, which, although, dasyprocta,
# Nearest to to: would, through, can, analogue, paine, reflects, for, callithrix,
# Nearest to while: but, and, however, thibetanus, synchronisation, although, are, or,
# Nearest to years: chd, shunt, dn, prism, genitive, four, resentment, pca,
# Nearest to many: some, several, these, such, all, agave, microcebus, other,
# Nearest to by: was, be, in, as, dasyprocta, microcebus, been, is,
# Average loss at step 72000 : 4.8073473562
# Average loss at step 74000 : 4.76561316699
# Average loss at step 76000 : 4.88699366701
# Average loss at step 78000 : 4.78014826488
# Average loss at step 80000 : 4.79962052274
# Nearest to between: with, in, microcebus, abruptly, during, tejada, clo, among,
# Nearest to zero: five, eight, six, seven, four, nine, three, michelob,
# Nearest to as: amo, thibetanus, escuela, chalukyas, became, using, naaman, dasyprocta,
# Nearest to its: their, his, the, saguinus, iit, ecc, compositions, ibrahim,
# Nearest to these: some, many, such, all, which, watch, other, are,
# Nearest to and: or, but, abet, phi, thibetanus, cegep, dasyprocta, callithrix,
# Nearest to d: b, propagate, cru, neville, modulo, retort, zero, UNK,
# Nearest to will: would, can, may, could, should, must, to, did,
# Nearest to be: been, have, were, by, are, is, was, not,
# Nearest to time: reuptake, dasyprocta, abitibi, privateer, michelob, ruse, por, incompressible,
# Nearest to but: and, however, while, although, prism, dasyprocta, escuela, zapatista,
# Nearest to to: would, through, paine, analogue, callithrix, initiating, can, nine,
# Nearest to while: but, and, however, although, thibetanus, when, synchronisation, are,
# Nearest to years: shunt, chd, pikes, months, resentment, prism, dn, year,
# Nearest to many: some, several, these, all, such, various, microcebus, agave,
# Nearest to by: was, be, in, despite, with, dasyprocta, after, microcebus,
# Average loss at step 82000 : 4.80557670307
# Average loss at step 84000 : 4.80185820949
# Average loss at step 86000 : 4.74700660121
# Average loss at step 88000 : 4.6946596024
# Average loss at step 90000 : 4.76303336811
# Nearest to between: with, in, microcebus, abruptly, during, clo, among, cebus,
# Nearest to zero: five, seven, six, eight, four, nine, three, callithrix,
# Nearest to as: amo, escuela, thibetanus, became, chalukyas, dasyprocta, naaman, in,
# Nearest to its: their, his, the, her, iit, compositions, some, saguinus,
# Nearest to these: some, many, such, all, which, several, they, there,
# Nearest to and: or, but, abet, including, thibetanus, microcebus, dasyprocta, callithrix,
# Nearest to d: b, zero, propagate, cru, six, thaler, isu, soy,
# Nearest to will: would, can, may, could, should, must, cannot, did,
# Nearest to be: been, have, were, by, are, is, was, not,
# Nearest to time: dasyprocta, reuptake, privateer, michelob, abitibi, ruse, por, preserve,
# Nearest to but: and, however, while, although, which, escuela, prism, dasyprocta,
# Nearest to to: would, through, paine, initiating, nine, analogue, callithrix, will,
# Nearest to while: but, although, and, however, when, thibetanus, synchronisation, or,
# Nearest to years: chd, shunt, months, year, resentment, prism, dn, goo,
# Nearest to many: some, several, these, all, various, such, agave, most,
# Nearest to by: was, be, after, as, despite, beeb, dasyprocta, callithrix,
# Average loss at step 92000 : 4.70445485067
# Average loss at step 94000 : 4.62043321025
# Average loss at step 96000 : 4.72983259487
# Average loss at step 98000 : 4.61200133646
# Average loss at step 100000 : 4.67257610321
# Nearest to between: with, in, microcebus, abruptly, among, during, tejada, clo,
# Nearest to zero: five, eight, six, seven, four, nine, three, iit,
# Nearest to as: thibetanus, escuela, amo, dasyprocta, became, chalukyas, naaman, conical,
# Nearest to its: their, his, the, her, some, compositions, iit, our,
# Nearest to these: some, many, such, all, several, which, the, their,
# Nearest to and: or, but, abet, while, including, cegep, dasyprocta, microcebus,
# Nearest to d: b, propagate, cru, keto, thaler, iit, isu, venezuela,
# Nearest to will: would, can, may, could, should, must, to, might,
# Nearest to be: been, have, are, by, were, not, is, was,
# Nearest to time: dasyprocta, reuptake, michelob, privateer, abitibi, thibetanus, preserve, callithrix,
# Nearest to but: and, however, while, although, escuela, when, or, dasyprocta,
# Nearest to to: through, would, paine, initiating, callithrix, will, nine, analogue,
# Nearest to while: but, and, although, however, when, synchronisation, are, where,
# Nearest to years: chd, year, months, shunt, goo, pikes, resentment, four,
# Nearest to many: some, several, these, all, various, such, most, microcebus,
# Nearest to by: be, was, despite, dasyprocta, microcebus, after, through, in,

# %%
final_embeddings
# Out:
# array([[-0.02782757, -0.16879494, -0.06111901, ..., -0.25700757,
#         -0.07137159,  0.0191142 ],
#        [-0.00155336, -0.00928817, -0.0535327 , ..., -0.23261793,
#         -0.13980433,  0.18055709],
#        [ 0.02576068, -0.06805354, -0.03688766, ..., -0.15378961,
#          0.00459271,  0.0717089 ],
#        ...,
#        [ 0.01061165, -0.09820389, -0.09913248, ...,  0.00818674,
#         -0.12992384,  0.05826835],
#        [ 0.0849214 , -0.14137401,  0.09674817, ...,  0.04111136,
#         -0.05420518, -0.01920278],
#        [ 0.08318492, -0.08202577,  0.11284919, ...,  0.03887166,
#          0.01556483,  0.12496017]], dtype=float32)

# %% [markdown]
# ## 6. 以視覺化的方式呈現結果

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.savefig(filename)
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
labels = [reverse_dictionary[i] for i in xrange(plot_only)]
plot_with_labels(low_dim_embs, labels)
# Out:
# /Users/markchang/.pyenv/versions/anaconda-2.4.0/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ## 7. 求出語意相近的字

# %%
def get_most_similar(word, top=10):
    wid = dictionary.get(word,-1)
    if wid == -1:
        print("word %s is not in the dictionary"%word)
    else:
        result_sim = np.dot(final_embeddings[wid:wid+1,:],final_embeddings.T)[0].argsort().tolist()
        result_sim.reverse()
        for idx in result_sim[:10]:
            print(reverse_dictionary[idx])

# %%
get_most_similar("one")
# Out:
# one
# six
# two
# four
# seven
# three
# five
# michelob
# eight
# agouti

# %%
get_most_similar("should")
# Out:
# should
# can
# would
# could
# must
# may
# will
# might
# recruited
# noted
